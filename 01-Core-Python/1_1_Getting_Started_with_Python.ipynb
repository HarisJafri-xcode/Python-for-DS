# %% [markdown]
# <a href="https://colab.research.google.com/github/HarisJafri-xcode/Python-for-Data-Science/blob/main/01-Core-Python/1_1_Getting_Started_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # print() Function

# %% [markdown]
# The built-in Python function print() is the most fundamental and commonly used function for producing output. Its primary purpose is to display specified messages or values to the standard output device, which is typically the console or screen.

# %% [markdown]
# print() Function receives Arguments from our end. The Argument can be Number, Text or a Mathematical Expression.

# %%
print(60)
# Out:
# 60

# %%
print(13.1)
# Out:
# 13.1

# %%
print("We are going to Learn Python for Data Science")
# Out:
# We are going to Learn Python for Data Science

# %%
print(2+2-3)
# Out:
# 1

# %% [markdown]
# As you noticed, the Text needs to be enclosed inside Qoutes. Qoutes can be single or Double Qoutes.

# %% [markdown]
# Machine will refuse to understand the Instructions if there are errors. Even the tinest typo in your Code shall result in an Error.
#
# Even Experienced Programmers make mistakes. So if you are making Mistakes, it's ok. You are on right Track.

# %% [markdown]
# # Integer and Float

# %% [markdown]
# Computers process and store Data in different ways depending on its Format.
#
# Operating with Numerical Data in Python allows you to perform Calculations, automate Formulas and Solve Numerical Problems.
#
# You can use Python to operate with Numbers.
#
# To output the result of a Calculation, we just need to enter the Mathematical Operations right into the print() Function.

# %%
print(20+3)
# Out:
# 23

# %%
print(20-3)
# Out:
# 17

# %%
print(20*3)
# Out:
# 60

# %%
print(20/3)
# Out:
# 6.666666666666667

# %%
print(20**3)
# Out:
# 8000

# %%
print(20//3)
# Out:
# 6

# %%
print(20%3)
# Out:
# 2

# %% [markdown]
# All the Operators are called "Arithmetic Operators" and they are used for Basic Mathematical Operations !
#
# Did you notice somthing ?
#
# We were executing Arithmetic Operations between Numbers without a Decimal Point.
#
# In Python, whenever we use Numeric Values without a Decimal Point, we refer to the Data Type as Integers.
#
# The Arithmetic Operations between Integers result in an Integer only ! Except for Division Operator.
#
# The Output when we used Division Operators between two Integers resulted in a Float.
#
# Floats are Numbers in Python with a Decimal Point.

# %% [markdown]
# ## When a Output of Arithmetic Operation is Float ?

# %% [markdown]
# There is 1 Division Operator in the Arithmetic Calculation.

# %%
print(2+3*4**2-(6/3))
# Out:
# 48.0

# %% [markdown]
# There is atleast 1 Float Data Type in the Arithmetic Operation.

# %%
print(3+4*2-1%2+5.0)
# Out:
# 15.0

# %% [markdown]
# Python follows PEDMAS Rule while performing Arithmetic Operations i.e., Parenthesis, Exponents, Divison, Multiplication, Addition and Subtraction.

# %% [markdown]
# # Strings

# %% [markdown]
# Another Data Type is called Strings. Whenever we enclose anything Single or Double Quotes.
#
# That is Text !
#
# Text is known as String in Built-in Python !

# %%
print("Data is the New Oil!")
# Out:
# Data is the New Oil!

# %%
print('Data Analysis needs Mathematical Foundations.')
# Out:
# Data Analysis needs Mathematical Foundations.

# %% [markdown]
# Anything inside Quote shall be treated as a piece of Text.

# %%
print("21+3")
# Out:
# 21+3

# %% [markdown]
# ## Quote inside String
# There are three main ways to handle quotes that are part of your string content:

# %% [markdown]
# ### The Escape Sequence

# %%
print("She said to me,\"You are a Good Man.\"")
# Out:
# She said to me,"You are a Good Man."

# %%
print('It\'s a great time!')
# Out:
# It's a great time!

# %% [markdown]
# ### Opposite Quotes

# %%
print("She said to me,'You are a Good Man.'")
# Out:
# She said to me,'You are a Good Man.'

# %%
print("It's a great time!")
# Out:
# It's a great time!

# %% [markdown]
# ### Using Triple Quotes

# %%
print("""She said to me,"It's a Great Time!" """)
# Out:
# She said to me,"It's a Great Time!"

# %% [markdown]
# ## Mathematical Operators with Strings

# %% [markdown]
# A String can be concatenated with another String.

# %%
print('Iron'+"Man"+'2')
# Out:
# IronMan2

# %% [markdown]
# A String can multiply with an Integer.

# %%
print("Yo"*3)
# Out:
# YoYoYo

# %%
print('5'*5)
# Out:
# 55555

# %% [markdown]
# # Commas

# %% [markdown]
# There are situations where we might want to use print() Function multiple times.
#
# Each print() instruction outputs the text in a new line.

# %%
print(20+3)
print("Hi")
print(19.75)
# Out:
# 23
# Hi
# 19.75

# %% [markdown]
# A Line of Code is called "Statement".
#
# When you give Computers many Statements, the Instruction will be executed line by line, from Top to Bottom.

# %% [markdown]
# The print() Functions can take in multiple values to output on the same line.
#
# This can be done by seperating them with Commas.

# %%
print("Balance:", 500)
# Out:
# Balance: 500

# %%
print("We need to give them",500,"US Dollars.")
# Out:
# We need to give them 500 US Dollars.

# %% [markdown]
# By default, the print() function separates arguments with a space; however, this can be customized by passing an argument using the "sep=" parameter.

# %%
print("Iron","Man",sep="-")
# Out:
# Iron-Man

# %%
print("companyname","email.com",sep="@")
# Out:
# companyname@email.com

# %% [markdown]
# # Comments

# %% [markdown]
# You can add comments to your Code to add Annotations and Explanations.
#
# Comments make the Code easier to understand for Humans while Computers ignore Comments.
#
# A Comment in Python with #

# %%
print(23+7) # Add 23 and 7 and Output it on Screen
# Out:
# 30

# %%
# Saying Hello to Sam
print("Hello Sam!")
# Out:
# Hello Sam!

# %% [markdown]
# # Variables

# %% [markdown]
# Variables act like a Box in which we can store Python Objects like Strings, Integers and Floats.

# %%
age = 31 # Assigning Integer Object to Variable "age"
hourly_wage = 20.5 # Assigning Float Object to Variable "hourly_wage"
print("The Hourly Wage offered by this Company is",hourly_wage,"and minimum age of Qualification is",age)
# Out:
# The Hourly Wage offered by this Company is 20.5 and minimum age of Qualification is 31

# %%
country = "Panama" # Assigning String Object to Variable "country"
print("Country Name:", country)

country = "Mexico" # Assigning a New String Object to Variable "country"
print("Country Name:", country)
# Out:
# Country Name: Panama
# Country Name: Mexico

# %%
# We already have Integer Object 31 stored inside Variable "age"
print("You shall be",age + 2,"years old after 2 Years!")
# Out:
# You shall be 33 years old after 2 Years!

# %%
# adding two Numerics
print(age + hourly_wage)
# Out:
# 51.5

# %% [markdown]
# By the way, "=" is called the Assignment Operator !
#
# Assignment Operator is used to assign Python Objects to Variables!

# %%
x = 5 # Assigning Integer Object to Variable "x"

x = x + 3 # Adding 3 in Variable "x" and reassigning this new output Python Object to the same Variable x

print(x)

x = x * 2 # Multiplying 2 with Variable "x" and reassigning this new output Python Object to the same Variable x

print(x)
# Out:
# 8
# 16

# %% [markdown]
# Variables names have certain conditions !
# 1. We may use Alphabets, Numbers and only 1 Special Character i.e., underscore
# 2. Variable Name can not begin with Numbers
# 3. Python is case sensitive therefore x and X are not the same Variables.
# 4. Python Keywords and Function should not be used as Variable Names.

# %% [markdown]
# # id() Function

# %% [markdown]
# id() Function actually returns the memory address where the object is currently stored in your computer's RAM (specifically, the virtual memory address used by the Python process).
#
# The primary use of id() in everyday Python programming is to check if two variables refer to the exact same object in memory

# %%
x = 1000
y = 1000

print("Memory Address of Python Object associated with Variable x:", id(x))
print("Memory Address of Python Object associated with Variable y:", id(y))
# Out:
# Memory Address of Python Object associated with Variable x: 136247772378576
# Memory Address of Python Object associated with Variable y: 136247772377136

# %% [markdown]
# Although the content of Python Object associated with Variable x and y is the same. They are stored in different Memory Address.
